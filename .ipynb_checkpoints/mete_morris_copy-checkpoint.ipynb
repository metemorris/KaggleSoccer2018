# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import sqlite3
import matplotlib.pyplot as plt

# %% [markdown]
# # Useful Info For loading Data
# https://www.kaggle.com/dimarudov/data-analysis-using-sql

# %% [markdown]
# Below we connect to the database

# %%
path = "../input/"  #Insert path here
database = path + 'database.sqlite'

conn = sqlite3.connect(database)

# %% [markdown]
# We load att the games with home goal, away goal and betting odds for different companies

# %%
detailed_bets = pd.read_sql("""SELECT home_team_goal, 
                                        away_team_goal,
                                        B365H,
                                        B365D,
                                        B365A,
                                        BWH,
                                        BWD,
                                        BWA,
                                        IWH,
                                        IWD,
                                        IWA,
                                        LBH,
                                        LBD,
                                        LBA,
                                        PSH,
                                        PSD,
                                        PSA,
                                        WHH,
                                        WHD,
                                        WHA,
                                        SJH,
                                        SJD,
                                        SJA,
                                        VCH,
                                        VCD,
                                        VCA,
                                        GBH,
                                        GBD,
                                        GBA,
                                        BSH,
                                        BSD,
                                        BSA
                                        
                                        
                                FROM Match;""", conn)

detailed_bets.shape
# Out:
# (25979, 32)

# %% [markdown]
# We check all the columns and see if there are lots of NaNs, we noticed that certain betting companies have lots of them

# %%
detailed_bets.isna().sum()
# Out:
# home_team_goal        0
# away_team_goal        0
# B365H              3387
# B365D              3387
# B365A              3387
# BWH                3404
# BWD                3404
# BWA                3404
# IWH                3459
# IWD                3459
# IWA                3459
# LBH                3423
# LBD                3423
# LBA                3423
# PSH               14811
# PSD               14811
# PSA               14811
# WHH                3408
# WHD                3408
# WHA                3408
# SJH                8882
# SJD                8882
# SJA                8882
# VCH                3411
# VCD                3411
# VCA                3411
# GBH               11817
# GBD               11817
# GBA               11817
# BSH               11818
# BSD               11818
# BSA               11818
# dtype: int64

# %% [markdown]
# We are dropping GB, BS, and PS betting companies because they have lots of nulls

# %%
detailed_bets_filtered = pd.read_sql("""SELECT home_team_goal, 
                                        away_team_goal,
                                        B365H,
                                        B365D,
                                        B365A,
                                        BWH,
                                        BWD,
                                        BWA,
                                        IWH,
                                        IWD,
                                        IWA,
                                        LBH,
                                        LBD,
                                        LBA,
                                        WHH,
                                        WHD,
                                        WHA,
                                        VCH,
                                        VCD,
                                        VCA
                                        
                                        
                                FROM Match;""", conn)

# %% [markdown]
# We drop all the matches that have lots of naans and get 17 000 games

# %%
cleaned_bets = detailed_bets_filtered.dropna(thresh=20) #drops vals if there are more than 1 Nan

cleaned_bets.shape
# Out:
# (22432, 20)

# %%
cleaned_bets['result'] = 0
cleaned_bets.loc[detailed_bets['home_team_goal'] < detailed_bets['away_team_goal'], 'result'] = -1
cleaned_bets.loc[detailed_bets['home_team_goal'] > detailed_bets['away_team_goal'], 'result'] = 1
cleaned_bets
# Out:
# C:\Users\Mete\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Mete\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#        home_team_goal  away_team_goal  B365H  B365D  B365A   BWH    BWD  \
# 0                   1               1   1.73   3.40   5.00  1.75   3.35
# 1                   0               0   1.95   3.20   3.60  1.80   3.30
# ...

# %%
bets_percentage = cleaned_bets[cleaned_bets.columns[2:20]] #take all the COLUMNS and take the reciprocal

# %%
bets_percentage = bets_percentage[bets_percentage.columns].rdiv(1)
bets_percentage
# Out:
#           B365H     B365D     B365A       BWH       BWD       BWA       IWH  \
# 0      0.578035  0.294118  0.200000  0.571429  0.298507  0.238095  0.540541
# 1      0.512821  0.312500  0.277778  0.555556  0.303030  0.253165  0.526316
# 2      0.420168  0.303030  0.363636  0.416667  0.303030  0.392157  0.384615
# 3      0.694444  0.266667  0.133333  0.714286  0.250000  0.147059  0.714286
# 4      0.200000  0.285714  0.606061  0.200000  0.285714  0.625000  0.250000
# 5      0.210526  0.294118  0.598802  0.206186  0.294118  0.606061  0.270270
# 6      0.476190  0.312500  0.303030  0.487805  0.307692  0.317460  0.540541
# 7      0.312500  0.294118  0.454545  0.392157  0.303030  0.416667  0.416667
# 8      0.444444  0.307692  0.347222  0.434783  0.307692  0.370370  0.476190
# 9      0.769231  0.190476  0.105263  0.800000  0.200000  0.100000  0.769231
# 10     0.769231  0.190476  0.105263  0.800000  0.200000  0.100000  0.769231
# ...

# %% [markdown]
# It does not add up to 1 because the odds are rigged!!!!!!!!!!!!!!!! /n
# There are two ways to fix this, we can either normalize or try to estimate the bookkeepers unbiased part or just leave it without /n
# Below will have normalized data

# %%
#split data into 3 column section each
#after splitting normalize each part by the sum of the rows
split_data = np.zeros((22432,3,6))
perc_odds = []
for i in range(0,6):
    start = i*3
    end = start+3
    bs=bets_percentage[bets_percentage.columns[start:end]]
    split_data[:,:,i] = (bs.T/bs.sum(axis=1)).T

# %%
norm_perc_data = np.vstack(split_data.T).T

# %%
norm_perc = pd.DataFrame(norm_perc_data,columns = bets_percentage.columns);

# %% [markdown]
# Below is normalized data for bets

# %%
norm_perc
# Out:
#           B365H     B365D     B365A       BWH       BWD       BWA       IWH  \
# 0      0.539135  0.274324  0.186541  0.515715  0.269403  0.214881  0.474677
# 1      0.464891  0.283293  0.251816  0.499712  0.272570  0.227717  0.468032
# 2      0.386598  0.278819  0.334583  0.374749  0.272545  0.352705  0.336797
# 3      0.634518  0.243655  0.121827  0.642722  0.224953  0.132325  0.628019
# 4      0.183188  0.261697  0.555115  0.180064  0.257235  0.562701  0.219055
# 5      0.190790  0.266545  0.542666  0.186363  0.265842  0.547795  0.237428
# 6      0.436183  0.286245  0.277571  0.438296  0.276464  0.285240  0.474677
# 7      0.294488  0.277165  0.428346  0.352705  0.272545  0.374749  0.363636
# 8      0.404276  0.279883  0.315841  0.390695  0.276492  0.332814  0.420624
# 9      0.722303  0.178856  0.098841  0.727273  0.181818  0.090909  0.679337
# 10     0.722303  0.178856  0.098841  0.727273  0.181818  0.090909  0.679337
# ...

# %%
labels_game = cleaned_bets['result']
labels_game.values
# Out:
# array([ 0,  0, -1, ...,  1,  0,  1], dtype=int64)

# %%
from collections import Counter
freqs = Counter(labels_game.values)

# %%
labels = 'Home Win','Draw','Away Win'
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 10}

plt.rc('font', **font)
fig1, ax1 = plt.subplots()
ax1.pie((freqs[1],freqs[0],freqs[-1]), labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
# Out:
# C:\Users\Mete\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis as QDA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn import neighbors
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

# %%
X = norm_perc[norm_perc.columns[0:3]].values
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(12,24))
fig.suptitle('Bet365 Odds', fontsize=14)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 12}
plt.rc('font', **font)
ax = plt.subplot(411, projection='3d')
ax.scatter(X[labels_game.values==1,0],X[labels_game.values==1,1],X[labels_game.values==1,2],alpha=0.8, c='blue')
ax.scatter(X[labels_game.values==0,0],X[labels_game.values==0,1],X[labels_game.values==0,2],alpha=0.5, c='red')
ax.scatter(X[labels_game.values==-1,0],X[labels_game.values==-1,1],X[labels_game.values==-1,2],alpha=0.05, c='yellow')
ax.set_xlabel('Home Win Percentage')
ax.set_ylabel('Draw Percentage')
ax.set_zlabel('Away Win Percentage')
ax2 = plt.subplot(412) 
ax2.scatter(X[labels_game.values==1,0],X[labels_game.values==1,1],alpha=0.8, c='blue')
ax2.scatter(X[labels_game.values==0,0],X[labels_game.values==0,1],alpha=0.5, c='red')
ax2.scatter(X[labels_game.values==-1,0],X[labels_game.values==-1,1],alpha=0.05, c='yellow')
ax2.set_xlabel('Home Win Percentage')
ax2.set_ylabel('Draw Percentage')
ax3 = plt.subplot(413) 
ax3.scatter(X[labels_game.values==1,0],X[labels_game.values==1,2],alpha=0.8, c='blue')
ax3.scatter(X[labels_game.values==0,0],X[labels_game.values==0,2],alpha=0.5, c='red')
ax3.scatter(X[labels_game.values==-1,0],X[labels_game.values==-1,2],alpha=0.05, c='yellow')
ax3.set_xlabel('Home Win Percentage')
ax3.set_ylabel('Away Win Percentage')
ax4 = plt.subplot(414) 
ax4.scatter(X[labels_game.values==1,1],X[labels_game.values==1,2],alpha=0.8, c='blue')
ax4.scatter(X[labels_game.values==0,1],X[labels_game.values==0,2],alpha=0.5, c='red')
ax4.scatter(X[labels_game.values==-1,1],X[labels_game.values==-1,2],alpha=0.05, c='yellow')
ax4.set_xlabel('Home Win Percentage')
ax4.set_ylabel('Away Win Percentage')
plt.show()
# Out:
# C:\Users\Mete\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
X = norm_perc[norm_perc.columns[3:6]].values
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(12,24))
fig.suptitle('BW Odds', fontsize=14)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 12}
plt.rc('font', **font)
ax = plt.subplot(411, projection='3d')
ax.scatter(X[labels_game.values==1,0],X[labels_game.values==1,1],X[labels_game.values==1,2],alpha=0.8, c='blue')
ax.scatter(X[labels_game.values==0,0],X[labels_game.values==0,1],X[labels_game.values==0,2],alpha=0.5, c='red')
ax.scatter(X[labels_game.values==-1,0],X[labels_game.values==-1,1],X[labels_game.values==-1,2],alpha=0.05, c='yellow')
ax.set_xlabel('Home Win Percentage')
ax.set_ylabel('Draw Percentage')
ax.set_zlabel('Away Win Percentage')
ax2 = plt.subplot(412) 
ax2.scatter(X[labels_game.values==1,0],X[labels_game.values==1,1],alpha=0.8, c='blue')
ax2.scatter(X[labels_game.values==0,0],X[labels_game.values==0,1],alpha=0.5, c='red')
ax2.scatter(X[labels_game.values==-1,0],X[labels_game.values==-1,1],alpha=0.05, c='yellow')
ax2.set_xlabel('Home Win Percentage')
ax2.set_ylabel('Draw Percentage')
ax3 = plt.subplot(413) 
ax3.scatter(X[labels_game.values==1,0],X[labels_game.values==1,2],alpha=0.8, c='blue')
ax3.scatter(X[labels_game.values==0,0],X[labels_game.values==0,2],alpha=0.5, c='red')
ax3.scatter(X[labels_game.values==-1,0],X[labels_game.values==-1,2],alpha=0.05, c='yellow')
ax3.set_xlabel('Home Win Percentage')
ax3.set_ylabel('Away Win Percentage')
ax4 = plt.subplot(414) 
ax4.scatter(X[labels_game.values==1,1],X[labels_game.values==1,2],alpha=0.8, c='blue')
ax4.scatter(X[labels_game.values==0,1],X[labels_game.values==0,2],alpha=0.5, c='red')
ax4.scatter(X[labels_game.values==-1,1],X[labels_game.values==-1,2],alpha=0.05, c='yellow')
ax4.set_xlabel('Home Win Percentage')
ax4.set_ylabel('Away Win Percentage')
plt.show()
# Out:
# C:\Users\Mete\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
X = norm_perc[norm_perc.columns[6:9]].values
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(12,24))
fig.suptitle('IW Odds', fontsize=14)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 12}
plt.rc('font', **font)
ax = plt.subplot(411, projection='3d')
ax.scatter(X[labels_game.values==1,0],X[labels_game.values==1,1],X[labels_game.values==1,2],alpha=0.8, c='blue')
ax.scatter(X[labels_game.values==0,0],X[labels_game.values==0,1],X[labels_game.values==0,2],alpha=0.5, c='red')
ax.scatter(X[labels_game.values==-1,0],X[labels_game.values==-1,1],X[labels_game.values==-1,2],alpha=0.05, c='yellow')
ax.set_xlabel('Home Win Percentage')
ax.set_ylabel('Draw Percentage')
ax.set_zlabel('Away Win Percentage')
ax2 = plt.subplot(412) 
ax2.scatter(X[labels_game.values==1,0],X[labels_game.values==1,1],alpha=0.8, c='blue')
ax2.scatter(X[labels_game.values==0,0],X[labels_game.values==0,1],alpha=0.5, c='red')
ax2.scatter(X[labels_game.values==-1,0],X[labels_game.values==-1,1],alpha=0.05, c='yellow')
ax2.set_xlabel('Home Win Percentage')
ax2.set_ylabel('Draw Percentage')
ax3 = plt.subplot(413) 
ax3.scatter(X[labels_game.values==1,0],X[labels_game.values==1,2],alpha=0.8, c='blue')
ax3.scatter(X[labels_game.values==0,0],X[labels_game.values==0,2],alpha=0.5, c='red')
ax3.scatter(X[labels_game.values==-1,0],X[labels_game.values==-1,2],alpha=0.05, c='yellow')
ax3.set_xlabel('Home Win Percentage')
ax3.set_ylabel('Away Win Percentage')
ax4 = plt.subplot(414) 
ax4.scatter(X[labels_game.values==1,1],X[labels_game.values==1,2],alpha=0.8, c='blue')
ax4.scatter(X[labels_game.values==0,1],X[labels_game.values==0,2],alpha=0.5, c='red')
ax4.scatter(X[labels_game.values==-1,1],X[labels_game.values==-1,2],alpha=0.05, c='yellow')
ax4.set_xlabel('Home Win Percentage')
ax4.set_ylabel('Away Win Percentage')
plt.show()
# Out:
# C:\Users\Mete\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
X = norm_perc[norm_perc.columns[9:12]].values
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(12,24))
fig.suptitle('LB Odds', fontsize=14)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 12}
plt.rc('font', **font)
ax = plt.subplot(411, projection='3d')
ax.scatter(X[labels_game.values==1,0],X[labels_game.values==1,1],X[labels_game.values==1,2],alpha=0.8, c='blue')
ax.scatter(X[labels_game.values==0,0],X[labels_game.values==0,1],X[labels_game.values==0,2],alpha=0.5, c='red')
ax.scatter(X[labels_game.values==-1,0],X[labels_game.values==-1,1],X[labels_game.values==-1,2],alpha=0.05, c='yellow')
ax.set_xlabel('Home Win Percentage')
ax.set_ylabel('Draw Percentage')
ax.set_zlabel('Away Win Percentage')
ax2 = plt.subplot(412) 
ax2.scatter(X[labels_game.values==1,0],X[labels_game.values==1,1],alpha=0.8, c='blue')
ax2.scatter(X[labels_game.values==0,0],X[labels_game.values==0,1],alpha=0.5, c='red')
ax2.scatter(X[labels_game.values==-1,0],X[labels_game.values==-1,1],alpha=0.05, c='yellow')
ax2.set_xlabel('Home Win Percentage')
ax2.set_ylabel('Draw Percentage')
ax3 = plt.subplot(413) 
ax3.scatter(X[labels_game.values==1,0],X[labels_game.values==1,2],alpha=0.8, c='blue')
ax3.scatter(X[labels_game.values==0,0],X[labels_game.values==0,2],alpha=0.5, c='red')
ax3.scatter(X[labels_game.values==-1,0],X[labels_game.values==-1,2],alpha=0.05, c='yellow')
ax3.set_xlabel('Home Win Percentage')
ax3.set_ylabel('Away Win Percentage')
ax4 = plt.subplot(414) 
ax4.scatter(X[labels_game.values==1,1],X[labels_game.values==1,2],alpha=0.8, c='blue')
ax4.scatter(X[labels_game.values==0,1],X[labels_game.values==0,2],alpha=0.5, c='red')
ax4.scatter(X[labels_game.values==-1,1],X[labels_game.values==-1,2],alpha=0.05, c='yellow')
ax4.set_xlabel('Home Win Percentage')
ax4.set_ylabel('Away Win Percentage')
plt.show()
# Out:
# C:\Users\Mete\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
X = norm_perc[norm_perc.columns[12:15]].values
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(12,24))
fig.suptitle('WH Odds', fontsize=14)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 12}
plt.rc('font', **font)
ax = plt.subplot(411, projection='3d')
ax.scatter(X[labels_game.values==1,0],X[labels_game.values==1,1],X[labels_game.values==1,2],alpha=0.8, c='blue')
ax.scatter(X[labels_game.values==0,0],X[labels_game.values==0,1],X[labels_game.values==0,2],alpha=0.5, c='red')
ax.scatter(X[labels_game.values==-1,0],X[labels_game.values==-1,1],X[labels_game.values==-1,2],alpha=0.05, c='yellow')
ax.set_xlabel('Home Win Percentage')
ax.set_ylabel('Draw Percentage')
ax.set_zlabel('Away Win Percentage')
ax2 = plt.subplot(412) 
ax2.scatter(X[labels_game.values==1,0],X[labels_game.values==1,1],alpha=0.8, c='blue')
ax2.scatter(X[labels_game.values==0,0],X[labels_game.values==0,1],alpha=0.5, c='red')
ax2.scatter(X[labels_game.values==-1,0],X[labels_game.values==-1,1],alpha=0.05, c='yellow')
ax2.set_xlabel('Home Win Percentage')
ax2.set_ylabel('Draw Percentage')
ax3 = plt.subplot(413) 
ax3.scatter(X[labels_game.values==1,0],X[labels_game.values==1,2],alpha=0.8, c='blue')
ax3.scatter(X[labels_game.values==0,0],X[labels_game.values==0,2],alpha=0.5, c='red')
ax3.scatter(X[labels_game.values==-1,0],X[labels_game.values==-1,2],alpha=0.05, c='yellow')
ax3.set_xlabel('Home Win Percentage')
ax3.set_ylabel('Away Win Percentage')
ax4 = plt.subplot(414) 
ax4.scatter(X[labels_game.values==1,1],X[labels_game.values==1,2],alpha=0.8, c='blue')
ax4.scatter(X[labels_game.values==0,1],X[labels_game.values==0,2],alpha=0.5, c='red')
ax4.scatter(X[labels_game.values==-1,1],X[labels_game.values==-1,2],alpha=0.05, c='yellow')
ax4.set_xlabel('Home Win Percentage')
ax4.set_ylabel('Away Win Percentage')
plt.show()
# Out:
# C:\Users\Mete\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
X = norm_perc[norm_perc.columns[15:18]].values
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(12,24))
fig.suptitle('VC Odds', fontsize=14)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 12}
plt.rc('font', **font)
ax = plt.subplot(411, projection='3d')
ax.scatter(X[labels_game.values==1,0],X[labels_game.values==1,1],X[labels_game.values==1,2],alpha=0.8, c='blue')
ax.scatter(X[labels_game.values==0,0],X[labels_game.values==0,1],X[labels_game.values==0,2],alpha=0.5, c='red')
ax.scatter(X[labels_game.values==-1,0],X[labels_game.values==-1,1],X[labels_game.values==-1,2],alpha=0.05, c='yellow')
ax.set_xlabel('Home Win Percentage')
ax.set_ylabel('Draw Percentage')
ax.set_zlabel('Away Win Percentage')
ax2 = plt.subplot(412) 
ax2.scatter(X[labels_game.values==1,0],X[labels_game.values==1,1],alpha=0.8, c='blue')
ax2.scatter(X[labels_game.values==0,0],X[labels_game.values==0,1],alpha=0.5, c='red')
ax2.scatter(X[labels_game.values==-1,0],X[labels_game.values==-1,1],alpha=0.05, c='yellow')
ax2.set_xlabel('Home Win Percentage')
ax2.set_ylabel('Draw Percentage')
ax3 = plt.subplot(413) 
ax3.scatter(X[labels_game.values==1,0],X[labels_game.values==1,2],alpha=0.8, c='blue')
ax3.scatter(X[labels_game.values==0,0],X[labels_game.values==0,2],alpha=0.5, c='red')
ax3.scatter(X[labels_game.values==-1,0],X[labels_game.values==-1,2],alpha=0.05, c='yellow')
ax3.set_xlabel('Home Win Percentage')
ax3.set_ylabel('Away Win Percentage')
ax4 = plt.subplot(414) 
ax4.scatter(X[labels_game.values==1,1],X[labels_game.values==1,2],alpha=0.8, c='blue')
ax4.scatter(X[labels_game.values==0,1],X[labels_game.values==0,2],alpha=0.5, c='red')
ax4.scatter(X[labels_game.values==-1,1],X[labels_game.values==-1,2],alpha=0.05, c='yellow')
ax4.set_xlabel('Home Win Percentage')
ax4.set_ylabel('Away Win Percentage')
plt.show()
# Out:
# C:\Users\Mete\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
data = bets_percentage
from sklearn import decomposition
pca = decomposition.PCA(data.shape[1], whiten=True)
B = pca.fit_transform(data)
E, L = pca.components_.T, pca.explained_variance_

# %%
plt.subplot(111,aspect='equal')
plt.plot(B[0,:],B[3,:], '.', alpha=0.2);
plt.subplot(211); plt.plot(L,'o-'); plt.ylabel('Eigenvalues');
plt.subplot(212); cl=np.cumsum(L); plt.ylabel('Total Variance');
plt.plot(cl,'o-r'); plt.ylim(0.353,.374);
plt.savefig("im3.png")
# Out:
# C:\Users\Mete\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

# %%
X_comb = [B[:,:3]]



# the target classes
y = cleaned_bets['result']# actual match outcomes
odds_company = ['b365', 'bw', 'iw', 'lb', 'wh', 'sj', 'vc', 'all']

cv_mean_knn = np.ones(1)

j=0
scoreswin = 0
scoresdraw=0
scoresloss=0

for X in X_comb:
        for i in range(1,2):
            
            cv_score = []
            cv_winscore=[]
        
            # split into train and test
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

            # instantiate learning model (k = 11)
            knn = KNeighborsClassifier(n_neighbors=11, weights='uniform')
    
            # fitting the model
            knn.fit(X_train, y_train)

            # predict the response
            # pred = knn.predict(X_test)
            # print(accuracy_score(y_test, pred)) 
            scores = cross_val_score(knn, X_test, y_test, cv=10, scoring='accuracy')
            scoreswin = cross_val_score(knn, X_test[y_test==1], y_test[y_test==1], cv=10, scoring='accuracy')
            scoresloss = cross_val_score(knn, X_test[y_test==-1], y_test[y_test==-1], cv=10, scoring='accuracy')
            scoresdraw = cross_val_score(knn, X_test[y_test==0], y_test[y_test==0], cv=10, scoring='accuracy')
            cv_score.append(scores.mean())
        cv_mean_knn[j] = np.mean(cv_score)
        j+=1

# %%
scores
X_test[y_test==-1]
y_test[y_test==-1]
# Out:
# 7365    -1
# 17717   -1
# 9304    -1
# 13659   -1
# 3549    -1
# 13745   -1
# 11293   -1
# 24399   -1
# 860     -1
# 601     -1
# 2664    -1
# 12949   -1
# 21387   -1
# 6527    -1
# 7608    -1
# 15538   -1
# 7272    -1
# 21020   -1
# 5035    -1
# 1287    -1
# 6830    -1
# 19888   -1
# 3494    -1
# 6747    -1
# 23013   -1
# 23255   -1
# 24405   -1
# 22514   -1
# 23235   -1
# 4280    -1
#         ..
# 6246    -1
# 22353   -1
# 21780   -1
# 10252   -1
# 15160   -1
# 14648   -1
# 1525    -1
# 4317    -1
# 6903    -1
# 12146   -1
# 21978   -1
# 2633    -1
# 6014    -1
# 9271    -1
# 11953   -1
# 4572    -1
# 15378   -1
# 22429   -1
# 1507    -1
# 7966    -1
# 3354    -1
# 20531   -1
# 12839   -1
# 1776    -1
# 7324    -1
# 6308    -1
# 17816   -1
# 22379   -1
# 7027    -1
# 18229   -1
# Name: result, Length: 284, dtype: int64

# %%
from sklearn.naive_bayes import GaussianNB

cv_mean_nb = np.ones(1)

j=0

for X in X_comb:
        for i in range(1,50):
            
            cv_score = []
        
            # split into train and test
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

            # instantiate learning model (k = 11)
            GNB = GaussianNB()
    
            # fitting the model
            GNB.fit(X_train, y_train)

            # predict the response
            # pred = knn.predict(X_test)
            # print(accuracy_score(y_test, pred)) 
            scores = cross_val_score(GNB, X_test, y_test, cv=10, scoring='accuracy')
            cv_score.append(scores.mean())
        cv_mean_nb[j] = np.mean(cv_score)
        j+=1

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis as QDA

cv_mean_qda = np.ones(1)

j=0

for X in X_comb:
        for i in range(1,50):
            
            cv_score = []
        
            # split into train and test
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

            # instantiate learning model (k = 11)
            qda = QDA()
    
            # fitting the model
            qda.fit(X_train, y_train)

            # predict the response
            # pred = knn.predict(X_test)
            # print(accuracy_score(y_test, pred)) 
            scores = cross_val_score(qda, X_test, y_test, cv=10, scoring='accuracy')
            cv_score.append(scores.mean())
        cv_mean_qda[j] = np.mean(cv_score)
        j+=1

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

cv_mean_lda = np.ones(1)

j=0

for X in X_comb:
        for i in range(1,50):
            
            cv_score = []
        
            # split into train and test
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

            # instantiate learning model (k = 11)
            lda = LDA()
    
            # fitting the model
            lda.fit(X_train, y_train)

            # predict the response
            # pred = knn.predict(X_test)
            # print(accuracy_score(y_test, pred)) 
            scores = cross_val_score(lda, X_test, y_test, cv=10, scoring='accuracy')
            cv_score.append(scores.mean())
        cv_mean_lda[j] = np.mean(cv_score)
        j+=1
# Out:
# C:\Users\Mete\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:442: UserWarning: The priors do not sum to 1. Renormalizing
#   UserWarning)
# C:\Users\Mete\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:442: UserWarning: The priors do not sum to 1. Renormalizing
#   UserWarning)
# C:\Users\Mete\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:442: UserWarning: The priors do not sum to 1. Renormalizing
#   UserWarning)
# C:\Users\Mete\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:442: UserWarning: The priors do not sum to 1. Renormalizing
#   UserWarning)
# C:\Users\Mete\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:442: UserWarning: The priors do not sum to 1. Renormalizing
#   UserWarning)
# C:\Users\Mete\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:442: UserWarning: The priors do not sum to 1. Renormalizing
#   UserWarning)
# ...

# %%
cv_scores = [cv_mean_knn, cv_mean_nb, cv_mean_lda, cv_mean_qda]

# %%
cv_scores
# Out:
# [array([0.46296871]),
#  array([0.53128995]),
#  array([0.54266879]),
#  array([0.51433571])]

# %%
X = B
fig = plt.figure(figsize=(12,24))
ax2 = plt.subplot(311) 
ax2.scatter(X[labels_game.values==1,0],X[labels_game.values==1,1],alpha=0.8, c='blue')
ax2.scatter(X[labels_game.values==0,0],X[labels_game.values==0,1],alpha=0.5, c='red')
ax2.scatter(X[labels_game.values==-1,0],X[labels_game.values==-1,1],alpha=0.05, c='yellow')
ax3 = plt.subplot(312) 
ax3.scatter(X[labels_game.values==1,0],X[labels_game.values==1,2],alpha=0.8, c='blue')
ax3.scatter(X[labels_game.values==0,0],X[labels_game.values==0,2],alpha=0.5, c='red')
ax3.scatter(X[labels_game.values==-1,0],X[labels_game.values==-1,2],alpha=0.05, c='yellow')
ax4 = plt.subplot(313) 
ax4.scatter(X[labels_game.values==1,1],X[labels_game.values==1,2],alpha=0.8, c='blue')
ax4.scatter(X[labels_game.values==0,1],X[labels_game.values==0,2],alpha=0.5, c='red')
ax4.scatter(X[labels_game.values==-1,1],X[labels_game.values==-1,2],alpha=0.05, c='yellow')
plt.show()
# Out:
# C:\Users\Mete\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
ax = plt.subplot(111, projection='3d')
ax.scatter(X[labels_game.values==1,0],X[labels_game.values==1,1],X[labels_game.values==1,2],alpha=0.8, c='blue')
ax.scatter(X[labels_game.values==0,0],X[labels_game.values==0,1],X[labels_game.values==0,2],alpha=0.5, c='red')
ax.scatter(X[labels_game.values==-1,0],X[labels_game.values==-1,1],X[labels_game.values==-1,2],alpha=0.05, c='yellow')
# Out:
# C:\Users\Mete\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
from sklearn.ensemble import RandomForestClassifier as RF

cv_mean_rf= np.ones(1)

j=0

for X in X_comb:
        for i in range(1,2):
            
            cv_score = []
        
            # split into train and test
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

            # instantiate learning model (k = 11)
            rf = RF(n_estimators =100)
    
            # fitting the model
            rf.fit(X_train, y_train)

            # predict the response
            # pred = knn.predict(X_test)
            # print(accuracy_score(y_test, pred)) 
            scores = cross_val_score(rf, X_test, y_test, cv=10, scoring='accuracy')
            cv_score.append(scores.mean())
        cv_mean_rf[j] = np.mean(cv_score)
        j+=1

# %%
cv_mean_rf
# Out:
# array([0.48472363])

# %%
from sklearn.tree import DecisionTreeClassifier as DT

cv_mean_dt= np.ones(1)

j=0

for X in X_comb:
        for i in range(1,2):
            
            cv_score = []
        
            # split into train and test
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

            # instantiate learning model (k = 11)
            dt = DT()
    
            # fitting the model
            dt.fit(X_train, y_train)

            # predict the response
            # pred = knn.predict(X_test)
            # print(accuracy_score(y_test, pred)) 
            scores = cross_val_score(dt, X_test, y_test, cv=10, scoring='accuracy')
            cv_score.append(scores.mean())
        cv_mean_dt[j] = np.mean(cv_score)
        j+=1

# %%
cv_mean_dt
# Out:
# array([0.43932871])

# %%
from sklearn.linear_model import LogisticRegression as LR

cv_mean_lr= np.ones(1)

j=0

for X in X_comb:
        for i in range(1,2):
            
            cv_score = []
        
            # split into train and test
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

            # instantiate learning model (k = 11)
            lr = LR()
    
            # fitting the model
            lr.fit(X_train, y_train)

            # predict the response
            # pred = knn.predict(X_test)
            # print(accuracy_score(y_test, pred)) 
            scores = cross_val_score(lr, X_test, y_test, cv=10, scoring='accuracy')
            cv_score.append(scores.mean())
        cv_mean_lr[j] = np.mean(cv_score)
        j+=1

# %%
cv_mean_lr
# Out:
# array([0.53925518])
